# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv("/content/placement (2).csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x='cgpa', y='resume_score', hue='placed', data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x_tr,x_te,y_tr,y_te=train_test_split(x,y,test_size=0.2)

# %%
x_tr
# Out:
#     cgpa  resume_score
# 96  8.23          7.76
# 80  7.83          7.70
# 59  5.95          7.57
# 17  7.81          8.71
# 57  6.34          7.21
# ..   ...           ...
# 19  6.75          8.11
# 78  5.79          5.66
# 14  7.51          6.25
# 98  8.14          5.63
# 15  8.88          5.93
#
# [80 rows x 2 columns]

# %%
pr= Perceptron()
pr.fit(x_tr,y_tr)
# Out:
# Perceptron()

# %%
pr.coef_
# Out:
# array([[ 46.74, -40.  ]])

# %%
plot_decision_regions(x_tr.values,y_tr.values,clf=pr, legend=2)
plt.show()
